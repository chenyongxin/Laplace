# %% [markdown]
# # 6 Blocks with $6h \times 6h \times 6h$ primary result

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Behind
#
# ### 1. Mean velocity. All statistics started from 4000 steps. Plot from 4000 to **** steps

# %% [markdown]
# * ### $\frac{u}{u_\tau}$

# %%
pwd
# Out:
# u'/home/chen/Documents/FASToLES/6Blocks/behind/behinduv'

# %%
cd /home/chen/Documents/FASToLES/6Blocks/behind/behindU/
# Out:
# /home/chen/Documents/FASToLES/6Blocks/behind/behindU

# %%
fig = plt.gcf()
plt.figure(figsize=(10,10))
dat = np.loadtxt("Step_5000U")
plt.plot(dat[:,1],dat[:,0],label="Until step_5000U mean flow",lw=2)
dat = np.loadtxt("Step_10000U")
plt.plot(dat[:,1],dat[:,0],label="Until step_10000U mean flow",lw=2)
dat = np.loadtxt("Step_15000U")
plt.plot(dat[:,1],dat[:,0],label="Until step_15000U mean flow",lw=2)
plt.legend(loc='best')
plt.xlabel('U Mean velocity')
plt.ylabel('Hight')
plt.show()

# %% [markdown]
# * ### $\dfrac{v}{u_\tau}$

# %%
fig = plt.gcf()
plt.figure(figsize=(10,10))
dat = np.loadtxt("Step_5000V")
plt.plot(dat[:,1],dat[:,0],label="Until step_5000V mean flow",lw=2)
dat = np.loadtxt("Step_10000V")
plt.plot(dat[:,1],dat[:,0],label="Until step_10000V mean flow",lw=2)
dat = np.loadtxt("Step_15000V")
plt.plot(dat[:,1],dat[:,0],label="Until step_15000V mean flow",lw=2)
plt.legend(loc='best')
plt.xlabel('V Mean velocity')
plt.ylabel('Hight')
plt.show()

# %% [markdown]
# * ### $\dfrac{w}{u_\tau}$

# %%
fig = plt.gcf()
plt.figure(figsize=(10,10))
dat = np.loadtxt("Step_5000W")
plt.plot(dat[:,1],dat[:,0],label="Until step_5000W mean flow",lw=2)
dat = np.loadtxt("Step_10000W")
plt.plot(dat[:,1],dat[:,0],label="Until step_10000W mean flow",lw=2)
dat = np.loadtxt("Step_15000W")
plt.plot(dat[:,1],dat[:,0],label="Until step_15000W mean flow",lw=2)
plt.legend(loc='best')
plt.xlabel('W Mean velocity')
plt.ylabel('Hight')
plt.show()

# %% [markdown]
# ### 2. Reynolds stress. All statistics started from 4000 steps. Plot from 4000 to **** steps

# %% [markdown]
# * ### $-\dfrac{u'v'}{u_\tau ^2}$

# %%
cd ../behinduv/
# Out:
# /home/chen/Documents/FASToLES/6Blocks/behind/behinduv

# %%
fig = plt.gcf()
plt.figure(figsize=(10,10))
dat = np.loadtxt("Step_5000uv")
plt.plot(dat[:,1],dat[:,0],label="Until step_5000 <u'v'>",lw=2)
dat = np.loadtxt("Step_10000uv")
plt.plot(dat[:,1],dat[:,0],label="Until step_10000 <u'v'>",lw=2)
dat = np.loadtxt("Step_15000uv")
plt.plot(dat[:,1],dat[:,0],label="Until step_15000 <u'v'>",lw=2)
plt.legend(loc='best')
plt.xlabel("Reynolds stress <u'v'>")
plt.ylabel('Hight')
plt.show()

# %% [markdown]
# * ### $\dfrac{v'w'}{u_\tau ^2}$

# %%
fig = plt.gcf()
plt.figure(figsize=(10,10))
dat = np.loadtxt("Step_5000vw")
plt.plot(dat[:,1],dat[:,0],label="Until step_5000 <v'w'>",lw=2)
dat = np.loadtxt("Step_10000vw")
plt.plot(dat[:,1],dat[:,0],label="Until step_10000 <v'w'>",lw=2)
dat = np.loadtxt("Step_15000vw")
plt.plot(dat[:,1],dat[:,0],label="Until step_15000 <v'w'>",lw=2)
plt.legend(loc='best')
plt.xlabel("Reynolds stress <v'w'>")
plt.ylabel('Hight')
plt.show()

# %% [markdown]
# * ### $\dfrac{u'w'}{u_\tau ^2}$

# %%
fig = plt.gcf()
plt.figure(figsize=(10,10))
dat = np.loadtxt("Step_5000uw")
plt.plot(dat[:,1],dat[:,0],label="Until step_5000 <u'w'>",lw=2)
dat = np.loadtxt("Step_10000uw")
plt.plot(dat[:,1],dat[:,0],label="Until step_10000 <u'w'>",lw=2)
dat = np.loadtxt("Step_15000uw")
plt.plot(dat[:,1],dat[:,0],label="Until step_15000 <u'w'>",lw=2)
plt.legend(loc='best')
plt.xlabel("Reynolds stress <u'w'>")
plt.ylabel('Hight')
plt.show()

# %% [markdown]
# ## Intersection
# ### 1. Mean velocity. All statistics started from 4000 steps. Plot from 4000 to **** steps
# * ### $\frac{u}{u_\tau}$

# %%
cd ../../inter/InterU/
# Out:
# /home/chen/Documents/FASToLES/6Blocks/inter/InterU

# %%
fig = plt.gcf()
plt.figure(figsize=(10,10))
dat = np.loadtxt("Step_10000U")
plt.plot(dat[:,1],dat[:,0],label="Until step_10000U mean flow",lw=2)
dat = np.loadtxt("Step_16000U")
plt.plot(dat[:,1],dat[:,0],label="Until step_16000U mean flow",lw=2)
dat = np.loadtxt("Step_20000U")
plt.plot(dat[:,1],dat[:,0],label="Until step_20000U mean flow",lw=2)
plt.legend(loc='best')
plt.xlabel('U Mean velocity')
plt.ylabel('Hight')
plt.show()

# %% [markdown]
# * ### $\frac{v}{u_\tau}$

# %%
fig = plt.gcf()
plt.figure(figsize=(10,10))
dat = np.loadtxt("Step_10000V")
plt.plot(dat[:,1],dat[:,0],label="Until step_10000V mean flow",lw=2)
dat = np.loadtxt("Step_16000V")
plt.plot(dat[:,1],dat[:,0],label="Until step_16000V mean flow",lw=2)
dat = np.loadtxt("Step_20000V")
plt.plot(dat[:,1],dat[:,0],label="Until step_20000V mean flow",lw=2)
plt.legend(loc='best')
plt.xlabel('V Mean velocity')
plt.ylabel('Hight')
plt.show()

# %% [markdown]
# * ### $\frac{w}{u_\tau}$

# %%
fig = plt.gcf()
plt.figure(figsize=(10,10))
dat = np.loadtxt("Step_10000W")
plt.plot(dat[:,1],dat[:,0],label="Until step_10000W mean flow",lw=2)
dat = np.loadtxt("Step_16000W")
plt.plot(dat[:,1],dat[:,0],label="Until step_16000W mean flow",lw=2)
dat = np.loadtxt("Step_20000W")
plt.plot(dat[:,1],dat[:,0],label="Until step_20000W mean flow",lw=2)
plt.legend(loc='best')
plt.xlabel('W Mean velocity')
plt.ylabel('Hight')
plt.show()

# %% [markdown]
# ### 2. Reynolds stress. All statistics started from 4000 steps. Plot from 4000 to **** steps

# %%
cd ../Interuv/
# Out:
# /home/chen/Documents/FASToLES/6Blocks/inter/Interuv

# %%
fig = plt.gcf()
plt.figure(figsize=(10,10))
dat = np.loadtxt("Step_10000uv")
plt.plot(dat[:,1],dat[:,0],label="Until step_10000 <u'v'>",lw=2)
plt.legend(loc='best')
plt.xlabel("Reynolds stress <u'v'>")
plt.ylabel('Hight')
plt.show()

# %%
fig = plt.gcf()
plt.figure(figsize=(10,10))
dat = np.loadtxt("Step_10000vw")
plt.plot(dat[:,1],dat[:,0],label="Until step_10000 <v'w'>",lw=2)
plt.legend(loc='best')
plt.xlabel("Reynolds stress <v'w'>")
plt.ylabel('Hight')
plt.show()

# %%
fig = plt.gcf()
plt.figure(figsize=(10,10))
dat = np.loadtxt("Step_10000uw")
plt.plot(dat[:,1],dat[:,0],label="Until step_10000 <u'w'>",lw=2)
plt.legend(loc='best')
plt.xlabel("Reynolds stress <u'w'>")
plt.ylabel('Hight')
plt.show()

# %% [markdown]
# ## 3. Comments
#
# ### Scaling
# $u_\tau$ is used to non-dimensionalization. However, the computation for friction velocity of channel with blocks is with problems.
#
# ### Oscillation especially in Reynolds stress
# 1. It could because resolution is not enough.
# 2. The procedure to compute reynolds stress maybe not so correct.. But haven't find issue here.
#
# ### Numerical method
# For wall immersed boundary condition:   Law of wall VS Velocity interpolation ?
